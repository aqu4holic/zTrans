# %%
import pandas as pd
import numpy as np

seed = 18022004
np.random.seed(seed)

# %%
data_prefix: str = 'data'
repo_prefix: str = f'{data_prefix}/repos'

original_df = pd.read_csv(f'{data_prefix}/classified_res.csv')

# %%
original_df
# Out:
#           id          fromLib                             toLib  \
# 0          0          ant:ant                org.apache.ant:ant
# 1          1          ant:ant                org.apache.ant:ant
# 2          2          ant:ant                org.apache.ant:ant
# 3          3          ant:ant                org.apache.ant:ant
# 4          4          ant:ant                org.apache.ant:ant
# ...      ...              ...                               ...
# 14329  14329  xstream:xstream  com.thoughtworks.xstream:xstream
# 14330  14330  xstream:xstream  com.thoughtworks.xstream:xstream
# 14331  14331  xstream:xstream  com.thoughtworks.xstream:xstream
# 14332  14332  xstream:xstream  com.thoughtworks.xstream:xstream
# 14333  14333  xstream:xstream  com.thoughtworks.xstream:xstream
#
#                        repoName                                  fileName  \
# 0           bobmcwhirter_drools                                   pom.xml
# 1            wocommunity_wolips               woproject-ant-tasks/pom.xml
# 2                   teiid_teiid                                   pom.xml
# 3             apache_axis2-java                    modules/parent/pom.xml
# 4             apache_axis2-java    modules/tool/axis2-idea-plugin/pom.xml
# ...                         ...                                       ...
# 14329  kiegroup_kogito-runtimes                       drools-core/pom.xml
# 14330        sakaiproject_sakai            gradebook/service/impl/pom.xml
# 14331        sakaiproject_sakai      gradebook/service/sakai-pack/pom.xml
# 14332            apache_shindig  1.0.x-incubating/java/social-api/pom.xml
# 14333            apache_shindig                  1.0.x-incubating/pom.xml
#
#                                     startCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 3      2233b385c9f07b726c11bd5e1e2c00a350622eb3
# 4      2233b385c9f07b726c11bd5e1e2c00a350622eb3
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       endCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 3      2233b385c9f07b726c11bd5e1e2c00a350622eb3
# 4      2233b385c9f07b726c11bd5e1e2c00a350622eb3
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       startCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 3                          +org.apache.ant:ant\n-ant:ant
# 4                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                         endCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 3                          +org.apache.ant:ant\n-ant:ant
# 4                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                       startCommitMessage  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...
# 1      Using Ant 1.7.1 as dependency for woproject-an...
# 2                                 updating ant groupid\n
# 3      fix the group id for latest version of ant\n\n...
# 4      fix the group id for latest version of ant\n\n...
# ...                                                  ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...
#
#                                         endCommitMessage startCommitTime  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...      2010-10-20
# 1      Using Ant 1.7.1 as dependency for woproject-an...      2008-09-06
# 2                                 updating ant groupid\n      2009-01-19
# 3      fix the group id for latest version of ant\n\n...      2007-02-05
# 4      fix the group id for latest version of ant\n\n...      2007-02-05
# ...                                                  ...             ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...      2007-08-25
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
#
#       endCommitTime  Category
# 0        2010-10-20         0
# 1        2008-09-06         0
# 2        2009-01-19         0
# 3        2007-02-05         0
# 4        2007-02-05         0
# ...             ...       ...
# 14329    2007-08-25        30
# 14330    2007-01-30        30
# 14331    2007-01-30        30
# 14332    2009-01-12        30
# 14333    2009-01-12        30
#
# [14334 rows x 14 columns]

# %%
test_unit_df = original_df[original_df['toLib'].str.contains('unit|test')]

test_unit_df
# Out:
#           id                              fromLib  \
# 45        45                              ant:ant
# 731      731      com.google.android:android-test
# 1125    1125  com.jayway.restassured:rest-assured
# 1358    1358         com.sun.jersey:jersey-bundle
# 3084    3084                    httpunit:httpunit
# ...      ...                                  ...
# 14308  14308                      xmlunit:xmlunit
# 14309  14309                      xmlunit:xmlunit
# 14310  14310                      xmlunit:xmlunit
# 14311  14311                      xmlunit:xmlunit
# 14312  14312                      xmlunit:xmlunit
#
#                                                    toLib  \
# 45                              org.apache.ant:ant-junit
# 731           com.google.testing.compile:compile-testing
# 1125   org.glassfish.jersey.test-framework.providers:...
# 1358   org.glassfish.jersey.test-framework.providers:...
# 3084                   net.sourceforge.htmlunit:htmlunit
# ...                                                  ...
# 14308                         org.xmlunit:xmlunit-legacy
# 14309                         org.xmlunit:xmlunit-legacy
# 14310                         org.xmlunit:xmlunit-legacy
# 14311                         org.xmlunit:xmlunit-legacy
# 14312                         org.xmlunit:xmlunit-legacy
#
#                               repoName  \
# 45                  wocommunity_wolips
# 731                  hoko_hoko-android
# 1125       meridor_perspective-backend
# 1358   opensecuritycontroller_osc-core
# 3084                    apache_archiva
# ...                                ...
# 14308             opendaylight_netconf
# 14309             opendaylight_netconf
# 14310           opendaylight_yangtools
# 14311           opendaylight_yangtools
# 14312          opendaylight_controller
#
#                                                 fileName  \
# 45                           woproject-ant-tasks/pom.xml
# 731                                              pom.xml
# 1125                                             pom.xml
# 1358                                  osc-common/pom.xml
# 3084   archiva-modules/archiva-web/archiva-webdav/pom...
# ...                                                  ...
# 14308         netconf/netconf-notifications-impl/pom.xml
# 14309              netconf/sal-netconf-connector/pom.xml
# 14310                     yang/yang-model-export/pom.xml
# 14311                        yang/yang-data-impl/pom.xml
# 14312  opendaylight/md-sal/sal-clustering-commons/pom...
#
#                                     startCommit  \
# 45     1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 731    c59afec9c1d13c21c118373a5e972805a2db5649
# 1125   6595e1a76e4179f0cd732d65819c7902c4ac3c60
# 1358   1de6cb2c58551212d572f33f2cad36dc533c92b7
# 3084   4825f8eb88ef35ca265903515ae715014bb4d597
# ...                                         ...
# 14308  652dada8b53d21c3eefb409b18365bbc29560afe
# 14309  652dada8b53d21c3eefb409b18365bbc29560afe
# 14310  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14311  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14312  e8c4d500b42c1b9b5d49b2f72a0c1cd9bcc42261
#
#                                       endCommit  \
# 45     1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 731    c59afec9c1d13c21c118373a5e972805a2db5649
# 1125   6595e1a76e4179f0cd732d65819c7902c4ac3c60
# 1358   1de6cb2c58551212d572f33f2cad36dc533c92b7
# 3084   4825f8eb88ef35ca265903515ae715014bb4d597
# ...                                         ...
# 14308  652dada8b53d21c3eefb409b18365bbc29560afe
# 14309  652dada8b53d21c3eefb409b18365bbc29560afe
# 14310  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14311  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14312  e8c4d500b42c1b9b5d49b2f72a0c1cd9bcc42261
#
#                                       startCommitChanges  \
# 45     +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 731    +org.easytesting:fest-assert-core\n+com.square...
# 1125   +org.glassfish.jersey.test-framework.providers...
# 1358   +javax.ws.rs:javax.ws.rs-api\n+org.glassfish.j...
# 3084   +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# ...                                                  ...
# 14308      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14309      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14310      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14311      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14312      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
#
#                                         endCommitChanges  \
# 45     +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 731    +org.easytesting:fest-assert-core\n+com.square...
# 1125   +org.glassfish.jersey.test-framework.providers...
# 1358   +javax.ws.rs:javax.ws.rs-api\n+org.glassfish.j...
# 3084   +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# ...                                                  ...
# 14308      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14309      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14310      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14311      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14312      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
#
#                                       startCommitMessage  \
# 45     Using Ant 1.7.1 as dependency for woproject-an...
# 731            [Updated] Unit Testing with Robolectric\n
# 1125                           Switched to Jersey-test\n
# 1358                                 Jersey 2 changes.\n
# 3084   remove use of old httpunit library\n\ngit-svn-...
# ...                                                  ...
# 14308  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
# 14309  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
# 14310  Migrate to to newer xmlunit\n\nThis migrates t...
# 14311  Migrate to to newer xmlunit\n\nThis migrates t...
# 14312  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
#
#                                         endCommitMessage startCommitTime  \
# 45     Using Ant 1.7.1 as dependency for woproject-an...      2008-09-06
# 731            [Updated] Unit Testing with Robolectric\n      2015-03-11
# 1125                           Switched to Jersey-test\n      2015-05-15
# 1358                                 Jersey 2 changes.\n      2017-02-07
# 3084   remove use of old httpunit library\n\ngit-svn-...      2014-01-06
# ...                                                  ...             ...
# 14308  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-20
# 14309  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-20
# 14310  Migrate to to newer xmlunit\n\nThis migrates t...      2018-08-17
# 14311  Migrate to to newer xmlunit\n\nThis migrates t...      2018-08-17
# 14312  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-17
#
#       endCommitTime  Category
# 45       2008-09-06         0
# 731      2015-03-11        24
# 1125     2015-05-15        35
# 1358     2017-02-07        21
# 3084     2014-01-06        28
# ...             ...       ...
# 14308    2018-08-20        43
# 14309    2018-08-20        43
# 14310    2018-08-17        43
# 14311    2018-08-17        43
# 14312    2018-08-17        43
#
# [1477 rows x 14 columns]

# %%
log_df = original_df[original_df['toLib'].str.contains('log|slf4j')]

log_df
# Out:
#           id                                            fromLib  \
# 180      180                      ch.qos.logback:logback-access
# 181      181                      ch.qos.logback:logback-access
# 182      182                      ch.qos.logback:logback-access
# 183      183                      ch.qos.logback:logback-access
# 184      184                      ch.qos.logback:logback-access
# ...      ...                                                ...
# 13789  13789                             org.slf4j:slf4j-simple
# 13836  13836  org.springframework.boot:spring-boot-starter-l...
# 13837  13837  org.springframework.boot:spring-boot-starter-l...
# 13838  13838  org.springframework.boot:spring-boot-starter-l...
# 13839  13839  org.springframework.boot:spring-boot-starter-l...
#
#                                      toLib  \
# 180     org.apache.logging.log4j:log4j-api
# 181     org.apache.logging.log4j:log4j-api
# 182    org.apache.logging.log4j:log4j-core
# 183    org.apache.logging.log4j:log4j-core
# 184     org.apache.logging.log4j:log4j-jcl
# ...                                    ...
# 13789           org.spf4j:spf4j-slf4j-test
# 13836       ch.qos.logback:logback-classic
# 13837       ch.qos.logback:logback-classic
# 13838   org.apache.logging.log4j:log4j-api
# 13839      commons-logging:commons-logging
#
#                                      repoName  \
# 180               flipkart-incubator_Poseidon
# 181               flipkart-incubator_Poseidon
# 182               flipkart-incubator_Poseidon
# 183               flipkart-incubator_Poseidon
# 184               flipkart-incubator_Poseidon
# ...                                       ...
# 13789                        zolyfarkas_spf4j
# 13836               HotelsDotCom_circus-train
# 13837               HotelsDotCom_circus-train
# 13838                         eclipse_hawkbit
# 13839  spring-cloud_spring-cloud-cloudfoundry
#
#                                           fileName  \
# 180                                        pom.xml
# 181                              container/pom.xml
# 182                                        pom.xml
# 183                              container/pom.xml
# 184                                        pom.xml
# ...                                            ...
# 13789                            spf4j-zel/pom.xml
# 13836         circus-train-s3-mapreduce-cp/pom.xml
# 13837                    circus-train-core/pom.xml
# 13838         examples/hawkbit-example-app/pom.xml
# 13839  spring-cloud-cloudfoundry-discovery/pom.xml
#
#                                     startCommit  \
# 180    2552502ec262f35c76d95856dbdec902884a9567
# 181    2552502ec262f35c76d95856dbdec902884a9567
# 182    2552502ec262f35c76d95856dbdec902884a9567
# 183    2552502ec262f35c76d95856dbdec902884a9567
# 184    2552502ec262f35c76d95856dbdec902884a9567
# ...                                         ...
# 13789  f5afbdf7dd26acf089e44f30c24e9122465f9d9b
# 13836  407ec931245c21503c0f13216129b114e8b3bd35
# 13837  407ec931245c21503c0f13216129b114e8b3bd35
# 13838  9d6527a3e29567c0c0b55951121d1356a65d7a3b
# 13839  1a55cc1c716d7fca26adeddea5a70575ad60f005
#
#                                       endCommit  \
# 180    2552502ec262f35c76d95856dbdec902884a9567
# 181    2552502ec262f35c76d95856dbdec902884a9567
# 182    2552502ec262f35c76d95856dbdec902884a9567
# 183    2552502ec262f35c76d95856dbdec902884a9567
# 184    2552502ec262f35c76d95856dbdec902884a9567
# ...                                         ...
# 13789  f5afbdf7dd26acf089e44f30c24e9122465f9d9b
# 13836  407ec931245c21503c0f13216129b114e8b3bd35
# 13837  407ec931245c21503c0f13216129b114e8b3bd35
# 13838  9d6527a3e29567c0c0b55951121d1356a65d7a3b
# 13839  1a55cc1c716d7fca26adeddea5a70575ad60f005
#
#                                       startCommitChanges  \
# 180    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 181    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 182    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 183    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 184    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# ...                                                  ...
# 13789  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 13836  +ch.qos.logback:logback-classic\n-org.springfr...
# 13837  +ch.qos.logback:logback-classic\n-org.springfr...
# 13838  +org.slf4j:jul-to-slf4j\n+org.slf4j:jcl-over-s...
# 13839  +commons-logging:commons-logging\n-org.springf...
#
#                                         endCommitChanges  \
# 180    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 181    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 182    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 183    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 184    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# ...                                                  ...
# 13789  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 13836  +ch.qos.logback:logback-classic\n-org.springfr...
# 13837  +ch.qos.logback:logback-classic\n-org.springfr...
# 13838  +org.slf4j:jul-to-slf4j\n+org.slf4j:jcl-over-s...
# 13839  +commons-logging:commons-logging\n-org.springf...
#
#                                       startCommitMessage  \
# 180    Using Log4J over logback (for both access and ...
# 181    Using Log4J over logback (for both access and ...
# 182    Using Log4J over logback (for both access and ...
# 183    Using Log4J over logback (for both access and ...
# 184    Using Log4J over logback (for both access and ...
# ...                                                  ...
# 13789                 [add] new spf4j-slf4j-test module!
# 13836        attempt to use logback (work in progress)\n
# 13837        attempt to use logback (work in progress)\n
# 13838  Switched back to Boots default logger: logback...
# 13839                         Fix logging dependencies\n
#
#                                         endCommitMessage startCommitTime  \
# 180    Using Log4J over logback (for both access and ...      2016-09-01
# 181    Using Log4J over logback (for both access and ...      2016-09-01
# 182    Using Log4J over logback (for both access and ...      2016-09-01
# 183    Using Log4J over logback (for both access and ...      2016-09-01
# 184    Using Log4J over logback (for both access and ...      2016-09-01
# ...                                                  ...             ...
# 13789                 [add] new spf4j-slf4j-test module!      2018-01-22
# 13836        attempt to use logback (work in progress)\n      2018-01-09
# 13837        attempt to use logback (work in progress)\n      2018-01-09
# 13838  Switched back to Boots default logger: logback...      2016-05-18
# 13839                         Fix logging dependencies\n      2015-05-21
#
#       endCommitTime  Category
# 180      2016-09-01        11
# 181      2016-09-01        11
# 182      2016-09-01        11
# 183      2016-09-01        11
# 184      2016-09-01        11
# ...             ...       ...
# 13789    2018-01-22        11
# 13836    2018-01-09        11
# 13837    2018-01-09        11
# 13838    2016-05-18        11
# 13839    2015-05-21        11
#
# [4418 rows x 14 columns]

# %%
remain_df = original_df[~original_df['toLib'].str.contains('log|slf4j|unit|test')]

remain_df
# Out:
#           id          fromLib                             toLib  \
# 0          0          ant:ant                org.apache.ant:ant
# 1          1          ant:ant                org.apache.ant:ant
# 2          2          ant:ant                org.apache.ant:ant
# 3          3          ant:ant                org.apache.ant:ant
# 4          4          ant:ant                org.apache.ant:ant
# ...      ...              ...                               ...
# 14329  14329  xstream:xstream  com.thoughtworks.xstream:xstream
# 14330  14330  xstream:xstream  com.thoughtworks.xstream:xstream
# 14331  14331  xstream:xstream  com.thoughtworks.xstream:xstream
# 14332  14332  xstream:xstream  com.thoughtworks.xstream:xstream
# 14333  14333  xstream:xstream  com.thoughtworks.xstream:xstream
#
#                        repoName                                  fileName  \
# 0           bobmcwhirter_drools                                   pom.xml
# 1            wocommunity_wolips               woproject-ant-tasks/pom.xml
# 2                   teiid_teiid                                   pom.xml
# 3             apache_axis2-java                    modules/parent/pom.xml
# 4             apache_axis2-java    modules/tool/axis2-idea-plugin/pom.xml
# ...                         ...                                       ...
# 14329  kiegroup_kogito-runtimes                       drools-core/pom.xml
# 14330        sakaiproject_sakai            gradebook/service/impl/pom.xml
# 14331        sakaiproject_sakai      gradebook/service/sakai-pack/pom.xml
# 14332            apache_shindig  1.0.x-incubating/java/social-api/pom.xml
# 14333            apache_shindig                  1.0.x-incubating/pom.xml
#
#                                     startCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 3      2233b385c9f07b726c11bd5e1e2c00a350622eb3
# 4      2233b385c9f07b726c11bd5e1e2c00a350622eb3
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       endCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 3      2233b385c9f07b726c11bd5e1e2c00a350622eb3
# 4      2233b385c9f07b726c11bd5e1e2c00a350622eb3
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       startCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 3                          +org.apache.ant:ant\n-ant:ant
# 4                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                         endCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 3                          +org.apache.ant:ant\n-ant:ant
# 4                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                       startCommitMessage  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...
# 1      Using Ant 1.7.1 as dependency for woproject-an...
# 2                                 updating ant groupid\n
# 3      fix the group id for latest version of ant\n\n...
# 4      fix the group id for latest version of ant\n\n...
# ...                                                  ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...
#
#                                         endCommitMessage startCommitTime  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...      2010-10-20
# 1      Using Ant 1.7.1 as dependency for woproject-an...      2008-09-06
# 2                                 updating ant groupid\n      2009-01-19
# 3      fix the group id for latest version of ant\n\n...      2007-02-05
# 4      fix the group id for latest version of ant\n\n...      2007-02-05
# ...                                                  ...             ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...      2007-08-25
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
#
#       endCommitTime  Category
# 0        2010-10-20         0
# 1        2008-09-06         0
# 2        2009-01-19         0
# 3        2007-02-05         0
# 4        2007-02-05         0
# ...             ...       ...
# 14329    2007-08-25        30
# 14330    2007-01-30        30
# 14331    2007-01-30        30
# 14332    2009-01-12        30
# 14333    2009-01-12        30
#
# [8444 rows x 14 columns]

# %%
matching_rows = log_df.merge(test_unit_df)

matching_rows
# Out:
#       id                 fromLib                       toLib  \
# 0  13785  org.slf4j:slf4j-simple  org.spf4j:spf4j-slf4j-test
# 1  13786  org.slf4j:slf4j-simple  org.spf4j:spf4j-slf4j-test
# 2  13787  org.slf4j:slf4j-simple  org.spf4j:spf4j-slf4j-test
# 3  13788  org.slf4j:slf4j-simple  org.spf4j:spf4j-slf4j-test
# 4  13789  org.slf4j:slf4j-simple  org.spf4j:spf4j-slf4j-test
#
#            repoName             fileName  \
# 0  zolyfarkas_spf4j   spf4j-avro/pom.xml
# 1  zolyfarkas_spf4j   spf4j-joda/pom.xml
# 2  zolyfarkas_spf4j     spf4j-ui/pom.xml
# 3  zolyfarkas_spf4j  spf4j-junit/pom.xml
# 4  zolyfarkas_spf4j    spf4j-zel/pom.xml
#
#                                 startCommit  \
# 0  d321f19c34d5ee9fc91114d012553e66144b9692
# 1  d321f19c34d5ee9fc91114d012553e66144b9692
# 2  d321f19c34d5ee9fc91114d012553e66144b9692
# 3  d321f19c34d5ee9fc91114d012553e66144b9692
# 4  f5afbdf7dd26acf089e44f30c24e9122465f9d9b
#
#                                   endCommit  \
# 0  d321f19c34d5ee9fc91114d012553e66144b9692
# 1  d321f19c34d5ee9fc91114d012553e66144b9692
# 2  d321f19c34d5ee9fc91114d012553e66144b9692
# 3  d321f19c34d5ee9fc91114d012553e66144b9692
# 4  f5afbdf7dd26acf089e44f30c24e9122465f9d9b
#
#                                   startCommitChanges  \
# 0  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 1  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 2  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 3  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 4  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
#
#                                     endCommitChanges  \
# 0  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 1  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 2  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 3  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 4  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
#
#                    startCommitMessage                    endCommitMessage  \
# 0  [add] use spf4j-slf4j-test module!  [add] use spf4j-slf4j-test module!
# 1  [add] use spf4j-slf4j-test module!  [add] use spf4j-slf4j-test module!
# 2  [add] use spf4j-slf4j-test module!  [add] use spf4j-slf4j-test module!
# 3  [add] use spf4j-slf4j-test module!  [add] use spf4j-slf4j-test module!
# 4  [add] new spf4j-slf4j-test module!  [add] new spf4j-slf4j-test module!
#
#   startCommitTime endCommitTime  Category
# 0      2018-01-22    2018-01-22        11
# 1      2018-01-22    2018-01-22        11
# 2      2018-01-22    2018-01-22        11
# 3      2018-01-22    2018-01-22        11
# 4      2018-01-22    2018-01-22        11

# %%
merged_df = test_unit_df.merge(matching_rows, how='outer', indicator=True)
test_unit_df = merged_df[merged_df['_merge'] == 'left_only'].drop(columns='_merge')

# %%
test_unit_df
# Out:
#          id                              fromLib  \
# 0        45                              ant:ant
# 1       731      com.google.android:android-test
# 2      1125  com.jayway.restassured:rest-assured
# 3      1358         com.sun.jersey:jersey-bundle
# 4      3084                    httpunit:httpunit
# ...     ...                                  ...
# 1472  14308                      xmlunit:xmlunit
# 1473  14309                      xmlunit:xmlunit
# 1474  14310                      xmlunit:xmlunit
# 1475  14311                      xmlunit:xmlunit
# 1476  14312                      xmlunit:xmlunit
#
#                                                   toLib  \
# 0                              org.apache.ant:ant-junit
# 1            com.google.testing.compile:compile-testing
# 2     org.glassfish.jersey.test-framework.providers:...
# 3     org.glassfish.jersey.test-framework.providers:...
# 4                     net.sourceforge.htmlunit:htmlunit
# ...                                                 ...
# 1472                         org.xmlunit:xmlunit-legacy
# 1473                         org.xmlunit:xmlunit-legacy
# 1474                         org.xmlunit:xmlunit-legacy
# 1475                         org.xmlunit:xmlunit-legacy
# 1476                         org.xmlunit:xmlunit-legacy
#
#                              repoName  \
# 0                  wocommunity_wolips
# 1                   hoko_hoko-android
# 2         meridor_perspective-backend
# 3     opensecuritycontroller_osc-core
# 4                      apache_archiva
# ...                               ...
# 1472             opendaylight_netconf
# 1473             opendaylight_netconf
# 1474           opendaylight_yangtools
# 1475           opendaylight_yangtools
# 1476          opendaylight_controller
#
#                                                fileName  \
# 0                           woproject-ant-tasks/pom.xml
# 1                                               pom.xml
# 2                                               pom.xml
# 3                                    osc-common/pom.xml
# 4     archiva-modules/archiva-web/archiva-webdav/pom...
# ...                                                 ...
# 1472         netconf/netconf-notifications-impl/pom.xml
# 1473              netconf/sal-netconf-connector/pom.xml
# 1474                     yang/yang-model-export/pom.xml
# 1475                        yang/yang-data-impl/pom.xml
# 1476  opendaylight/md-sal/sal-clustering-commons/pom...
#
#                                    startCommit  \
# 0     1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 1     c59afec9c1d13c21c118373a5e972805a2db5649
# 2     6595e1a76e4179f0cd732d65819c7902c4ac3c60
# 3     1de6cb2c58551212d572f33f2cad36dc533c92b7
# 4     4825f8eb88ef35ca265903515ae715014bb4d597
# ...                                        ...
# 1472  652dada8b53d21c3eefb409b18365bbc29560afe
# 1473  652dada8b53d21c3eefb409b18365bbc29560afe
# 1474  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 1475  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 1476  e8c4d500b42c1b9b5d49b2f72a0c1cd9bcc42261
#
#                                      endCommit  \
# 0     1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 1     c59afec9c1d13c21c118373a5e972805a2db5649
# 2     6595e1a76e4179f0cd732d65819c7902c4ac3c60
# 3     1de6cb2c58551212d572f33f2cad36dc533c92b7
# 4     4825f8eb88ef35ca265903515ae715014bb4d597
# ...                                        ...
# 1472  652dada8b53d21c3eefb409b18365bbc29560afe
# 1473  652dada8b53d21c3eefb409b18365bbc29560afe
# 1474  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 1475  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 1476  e8c4d500b42c1b9b5d49b2f72a0c1cd9bcc42261
#
#                                      startCommitChanges  \
# 0     +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 1     +org.easytesting:fest-assert-core\n+com.square...
# 2     +org.glassfish.jersey.test-framework.providers...
# 3     +javax.ws.rs:javax.ws.rs-api\n+org.glassfish.j...
# 4     +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# ...                                                 ...
# 1472      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 1473      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 1474      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 1475      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 1476      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
#
#                                        endCommitChanges  \
# 0     +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 1     +org.easytesting:fest-assert-core\n+com.square...
# 2     +org.glassfish.jersey.test-framework.providers...
# 3     +javax.ws.rs:javax.ws.rs-api\n+org.glassfish.j...
# 4     +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# ...                                                 ...
# 1472      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 1473      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 1474      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 1475      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 1476      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
#
#                                      startCommitMessage  \
# 0     Using Ant 1.7.1 as dependency for woproject-an...
# 1             [Updated] Unit Testing with Robolectric\n
# 2                             Switched to Jersey-test\n
# 3                                   Jersey 2 changes.\n
# 4     remove use of old httpunit library\n\ngit-svn-...
# ...                                                 ...
# 1472  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
# 1473  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
# 1474  Migrate to to newer xmlunit\n\nThis migrates t...
# 1475  Migrate to to newer xmlunit\n\nThis migrates t...
# 1476  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
#
#                                        endCommitMessage startCommitTime  \
# 0     Using Ant 1.7.1 as dependency for woproject-an...      2008-09-06
# 1             [Updated] Unit Testing with Robolectric\n      2015-03-11
# 2                             Switched to Jersey-test\n      2015-05-15
# 3                                   Jersey 2 changes.\n      2017-02-07
# 4     remove use of old httpunit library\n\ngit-svn-...      2014-01-06
# ...                                                 ...             ...
# 1472  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-20
# 1473  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-20
# 1474  Migrate to to newer xmlunit\n\nThis migrates t...      2018-08-17
# 1475  Migrate to to newer xmlunit\n\nThis migrates t...      2018-08-17
# 1476  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-17
#
#      endCommitTime  Category
# 0       2008-09-06         0
# 1       2015-03-11        24
# 2       2015-05-15        35
# 3       2017-02-07        21
# 4       2014-01-06        28
# ...            ...       ...
# 1472    2018-08-20        43
# 1473    2018-08-20        43
# 1474    2018-08-17        43
# 1475    2018-08-17        43
# 1476    2018-08-17        43
#
# [1472 rows x 14 columns]

# %%
remain_df['toLib'].unique()
# Out:
# array(['org.apache.ant:ant', 'org.apache.ant:ant-apache-regexp',
#        'org.apache.ant:ant-nodeps', 'org.apache.ant:ant-trax',
#        'org.antlr:antlr-runtime', 'org.antlr:stringtemplate',
#        'com.google.inject.extensions:guice-jmx',
#        'com.google.inject:guice', 'org.springframework:spring-beans',
#        'org.springframework:spring-context',
#        'org.springframework:spring-core',
#        'net.sf.jopt-simple:jopt-simple', 'javassist:javassist',
#        'org.apache.openejb:asm-finder', 'org.ow2.asm:asm',
#        'org.ow2.asm:asm-commons', 'org.ow2.asm:asm-debug-all',
#        'org.apache.felix:org.apache.felix.scr.generator',
#        'org.apache.servicemix.bundles:org.apache.servicemix.bundles.asm',
#        'org.glassfish.external:asm-all-repackaged', 'org.ow2.asm:asm-all',
#        'org.ow2.asm:asm-analysis', 'org.ow2.asm:asm-tree',
#        'org.ow2.asm:asm-util', 'commons-pool:commons-pool',
#        'org.apache.bcel:bcel', 'com.alibaba:druid', 'com.mchange:c3p0',
#        'com.zaxxer:HikariCP', 'commons-dbcp:commons-dbcp',
#        'org.hibernate:hibernate-c3p0', 'org.codehaus.castor:castor',
#        'org.sonatype.sisu.inject:cglib', 'org.javassist:javassist',
#        'org.springframework.boot:spring-boot-dependencies',
#        'edu.stanford.protege:protege-launcher', 'com.blazegraph:colt',
#        'org.apache.mahout:mahout-math', 'com.github.sgroschupf:zkclient',
#        'org.apache.curator:curator-client',
#        'org.apache.curator:curator-framework',
#        'org.apache.curator:curator-recipes', 'com.caucho:hessian',
#        'org.apache.dubbo:dubbo',
#        'com.fasterxml.jackson.core:jackson-annotations',
#        'com.fasterxml.jackson.core:jackson-core',
#        'com.fasterxml.jackson.core:jackson-databind',
#        'net.sf.json-lib:json-lib',
#        'org.codehaus.jackson:jackson-core-asl',
#        'org.codehaus.jackson:jackson-mapper-asl',
#        'commons-cli:commons-cli', 'info.picocli:picocli',
#        'it.unimi.dsi:fastutil', 'net.openhft:koloboke-api-jdk6-7',
#        'net.openhft:koloboke-api-jdk8',
#        'net.openhft:koloboke-impl-jdk6-7',
#        'net.openhft:koloboke-impl-jdk8',
#        'io.dropwizard.metrics:metrics-core',
#        'com.datastax.oss:java-driver-query-builder',
#        'com.facebook.presto.cassandra:cassandra-driver',
#        'com.facebook.presto.cassandra:cassandra-server',
#        'info.archinnov:achilles-embedded',
#        'org.apache.ignite:ignite-cassandra-store',
#        'org.codehaus.mojo:cassandra-maven-plugin',
#        'org.hibernate:hibernate-search-elasticsearch',
#        'org.hibernate:hibernate-search-engine',
#        'com.esotericsoftware:kryo', 'com.esotericsoftware:kryo-shaded',
#        'com.esotericsoftware.kryo:kryo',
#        'com.fasterxml.jackson.datatype:jackson-datatype-joda',
#        'com.fasterxml.jackson.jaxrs:jackson-jaxrs-json-provider',
#        'com.fasterxml.jackson:jackson-bom', 'com.google.code.gson:gson',
#        'org.apache.geronimo.specs:geronimo-json_1.1_spec',
#        'org.apache.geronimo.specs:geronimo-jsonb_1.0_spec',
#        'org.apache.johnzon:johnzon-jsonb',
#        'org.codehaus.jackson:jackson-jaxrs',
#        'org.codehaus.jackson:jackson-smile',
#        'org.jboss.resteasy:resteasy-jackson-provider', 'org.json:json',
#        'org.springframework.boot:spring-boot-starter-json',
#        'com.alibaba:fastjson', 'org.apache.flink:flink-shaded-jackson',
#        'org.yaml:snakeyaml',
#        'com.github.joschi.jackson:jackson-datatype-threetenbp',
#        'com.fasterxml.jackson.module:jackson-module-jaxb-annotations',
#        'org.jboss.resteasy:jaxrs-api', 'javax.cache:cache-api',
#        'org.apache.camel:json-simple-ordered', 'com.101tec:zkclient',
#        'org.robolectric:android-all', 'org.robolectric:robolectric',
#        'com.github.spotbugs:spotbugs',
#        'com.github.spotbugs:spotbugs-annotations',
#        'com.github.stephenc.findbugs:findbugs-annotations',
#        'net.jcip:jcip-annotations', 'com.qulice:qulice-findbugs',
#        'com.github.stephenc.jcip:jcip-annotations',
#        'org.checkerframework:checker-compat-qual',
#        'org.checkerframework:checker-qual', 'org.jetbrains:annotations',
#        'com.squareup.retrofit2:converter-gson',
#        'com.squareup.retrofit2:converter-scalars',
#        'com.squareup.retrofit2:retrofit',
#        'org.jboss.resteasy:resteasy-jackson2-provider',
#        'com.google.guava:guava', 'com.github.ben-manes.caffeine:caffeine',
#        'com.googlecode.guava-osgi:guava-osgi',
#        'cz.seznam.euphoria:shaded-guava',
#        'org.apache.commons:commons-lang3',
#        'org.glassfish.jersey.bundles.repackaged:jersey-guava',
#        'org.eclipse.jetty:jetty-server',
#        'org.glassfish.jersey.core:jersey-server',
#        'org.eclipse.jetty:jetty-servlet',
#        'org.apache.httpcomponents:httpclient',
#        'com.google.gwt.inject:gin', 'com.squareup.dagger:dagger',
#        'com.squareup.dagger:dagger-compiler',
#        'org.sonatype.sisu:sisu-guice',
#        'com.github.rtyley:roboguice-sherlock', 'com.google.dagger:dagger',
#        'com.google.dagger:dagger-compiler', 'javax.inject:javax.inject',
#        'org.roboguice:roboguice', 'org.assertj:assertj-core',
#        'org.jmockit:jmockit', 'org.mockito:mockito-core',
#        'com.cedarsoftware:json-io', 'com.github.cliftonlabs:json-simple',
#        'com.thoughtworks.xstream:xstream', 'net.minidev:json-smart',
#        'hsqldb:hsqldb', 'mysql:mysql-connector-java',
#        'mysql:mysql-connector-mxj', 'net.openhft:chronicle-map',
#        'org.hsqldb:hsqldb', 'org.ikasan:ikasan-h2-standalone-persistence',
#        'org.xerial:sqlite-jdbc', 'postgresql:postgresql',
#        'org.ehcache.modules:ehcache-core',
#        'org.ehcache.modules:ehcache-impl',
#        'org.ehcache:ehcache-clustered', 'com.lowagie:itext',
#        'org.apache.pdfbox:pdfbox', 'org.awaitility:awaitility',
#        'com.jsoniter:jsoniter', 'io.rest-assured:json-path',
#        'io.rest-assured:json-schema-validator',
#        'io.rest-assured:rest-assured', 'io.rest-assured:spring-mock-mvc',
#        'org.jclouds.driver:jclouds-sshj', 'com.zaxxer:HikariCP-java6',
#        'org.apache.tomcat:tomcat-jdbc',
#        'com.googlecode.disruptor:disruptor',
#        'com.github.librepdf:openpdf', 'com.itextpdf:itextpdf',
#        'com.itextpdf:itext-pdfa', 'org.xhtmlrenderer:flying-saucer-fop',
#        'org.xhtmlrenderer:flying-saucer-pdf-openpdf',
#        'com.zaxxer:HikariCP-java7', 'org.apache.commons:commons-dbcp2',
#        'com.h2database:h2',
#        'org.springframework.cloud:spring-cloud-starter-netflix-hystrix',
#        'io.vertx:vertx-core', 'org.asynchttpclient:async-http-client',
#        'org.springframework.amqp:spring-rabbit',
#        'org.eclipse.jetty:jetty-http', 'org.hamcrest:hamcrest',
#        'com.jcabi:jcabi-http', 'com.squareup.okhttp3:okhttp',
#        'com.squareup.okhttp3:okhttp-urlconnection', 'javax.faces:jsf-api',
#        'org.glassfish:javax.faces',
#        'org.jboss.spec.javax.faces:jboss-jsf-api_2.0_spec',
#        'org.jboss.spec.javax.resource:jboss-connector-api_1.6_spec',
#        'org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_1.1_spec',
#        'org.jboss.spec.javax.xml.rpc:jboss-jaxrpc-api_1.1_spec',
#        'org.richfaces:richfaces',
#        'org.jboss.spec.javax.faces:jboss-jsf-api_2.1_spec',
#        'org.glassfish.jersey.media:jersey-media-multipart',
#        'org.glassfish.jersey.ext:jersey-spring3',
#        'org.glassfish.jersey.ext:jersey-spring4',
#        'org.springframework:spring-webmvc',
#        'org.glassfish.jersey.containers:jersey-container-servlet',
#        'org.glassfish.jersey.containers:jersey-container-servlet-core',
#        'org.glassfish.jersey.core:jersey-client',
#        'org.glassfish.jersey.core:jersey-common',
#        'org.glassfish.jersey.ext:jersey-bean-validation',
#        'org.glassfish.jersey.inject:jersey-hk2',
#        'org.glassfish.jersey.media:jersey-media-json-jackson',
#        'org.glassfish.jersey.media:jersey-media-json-jettison',
#        'javax.servlet:javax.servlet-api', 'org.glassfish.jaxb:jaxb-core',
#        'org.glassfish.jaxb:jaxb-runtime', 'javax.xml:jaxb-impl',
#        'org.glassfish.jaxb:jaxb-xjc',
#        'com.fasterxml.jackson.dataformat:jackson-dataformat-xml',
#        'com.sun.xml.bind:jaxb-impl', 'de.ruedigermoeller:fst',
#        'org.locationtech.jts:jts-core',
#        'com.codahale.metrics:metrics-core',
#        'io.dropwizard.metrics:metrics-annotation',
#        'io.dropwizard.metrics:metrics-ganglia',
#        'io.dropwizard.metrics:metrics-jvm',
#        'io.dropwizard.metrics:metrics-servlet',
#        'org.springframework.boot:spring-boot-starter-jdbc',
#        'org.apache.servicemix.bundles:org.apache.servicemix.bundles.commons-beanutils',
#        'args4j:args4j', 'com.beust:jcommander',
#        'net.sourceforge.collections:collections-generic',
#        'org.apache.commons:commons-collections4',
#        'org.apache.commons:commons-configuration2',
#        'org.apache.commons:commons-digester3',
#        'org.apache.httpcomponents:fluent-hc',
#        'org.apache.httpcomponents:httpcore',
#        'org.apache.httpcomponents:httpmime',
#        'org.apache.commons:commons-io', 'org.apache.commons:commons-text',
#        'org.apache.commons:commons-pool2',
#        'backport-util-concurrent:backport-util-concurrent', 'jaxen:jaxen',
#        'org.dom4j:dom4j', 'org.jdom:jdom', 'org.jdom:jdom2',
#        'com.github.kirviq:dumbster', 'org.subethamail:subethasmtp-wiser',
#        'org.easymock:easymock', 'org.easymock:easymockclassextension',
#        'org.freemarker:freemarker', 'org.codehaus.groovy:groovy-all',
#        'org.apache.derby:derby', 'org.apache.derby:derbyclient',
#        'org.apache.tomcat.embed:tomcat-embed-core',
#        'org.apache.tomcat:tomcat-juli', 'xerces:xercesImpl',
#        'io.cucumber:cucumber-java', 'io.cucumber:cucumber-java8',
#        'io.micrometer:micrometer-core',
#        'io.micrometer:micrometer-registry-influx',
#        'io.micrometer:micrometer-registry-prometheus',
#        'io.micrometer:micrometer-spring-legacy',
#        'com.codahale.metrics:metrics-jvm',
#        'com.codahale.metrics:metrics-servlets',
#        'org.springframework.boot:spring-boot-starter-web',
#        'com.google.protobuf:protobuf-java', 'org.jboss.netty:netty',
#        'de.ruedigermoeller:netty2go', 'org.apache.activemq:activemq-core',
#        'org.apache.flink:flink-shaded-netty',
#        'org.apache.hbase.thirdparty:hbase-shaded-netty',
#        'io.reactivex.rxjava2:rxjava',
#        'org.reactivestreams:reactive-streams',
#        'com.jayway.restassured:rest-assured',
#        'com.github.xiaoymin:swagger-bootstrap-ui',
#        'io.swagger.core.v3:swagger-annotations',
#        'org.glassfish.jersey.containers:jersey-container-grizzly2-http',
#        'io.netty:netty-all', 'fastutil:fastutil', 'com.vaadin:vaadin',
#        'net.sf.jasperreports:jasperreports', 'asm:asm-all',
#        'com.sun.activation:javax.activation',
#        'org.apache.geronimo.specs:geronimo-activation_1.1_spec',
#        'org.apache.geronimo.specs:geronimo-annotation_1.3_spec',
#        'org.jboss.spec.javax.annotation:jboss-annotations-api_1.3_spec',
#        'org.apache.geronimo.specs:geronimo-annotation_1.0_spec',
#        'org.jboss.spec.javax.annotation:jboss-annotations-api_1.1_spec',
#        'org.jboss.spec.javax.annotation:jboss-annotations-api_1.2_spec',
#        'org.springframework.boot:spring-boot-starter-cache',
#        'org.apache.tomcat:tomcat-el-api',
#        'org.jboss.spec.javax.el:jboss-el-api_2.2_spec',
#        'jakarta.el:jakarta.el-api', 'org.glassfish:javax.el',
#        'org.jboss.spec.javax.el:jboss-el-api_3.0_spec',
#        'jakarta.enterprise:jakarta.enterprise.cdi-api',
#        'com.sun.faces:jsf-api', 'com.sun.faces:jsf-impl',
#        'org.apache.geronimo.specs:geronimo-atinject_1.0_spec',
#        'org.apache.servicemix.bundles:org.apache.servicemix.bundles.javax-inject',
#        'jakarta.json:jakarta.json-api',
#        'javax.json.bind:javax.json.bind-api', 'org.glassfish:javax.json',
#        'com.sun.mail:javax.mail',
#        'org.apache.geronimo.specs:geronimo-javamail_1.4_spec',
#        'org.eclipse.persistence:javax.persistence',
#        'org.hibernate.javax.persistence:hibernate-jpa-2.1-api',
#        'org.hibernate:hibernate-core',
#        'jakarta.servlet:jakarta.servlet-api',
#        'jakarta.validation:jakarta.validation-api',
#        'org.apache.tomcat:tomcat-servlet-api',
#        'javax.servlet.jsp:javax.servlet.jsp-api',
#        'javax.servlet.jsp:jsp-api', 'org.apache.tomcat:tomcat-jsp-api',
#        'javax.servlet.jsp.jstl:javax.servlet.jsp.jstl-api',
#        'javax.servlet.jsp.jstl:jstl-api', 'jstl:jstl',
#        'org.apache.taglibs:taglibs-standard-jstlel',
#        'org.glassfish.web:jstl-impl',
#        'org.jboss.spec.javax.servlet.jstl:jboss-jstl-api_1.2_spec',
#        'org.eclipse.jetty.orbit:javax.servlet',
#        'org.jboss.spec.javax.transaction:jboss-transaction-api_1.1_spec',
#        'org.jboss.spec:jboss-javaee-6.0',
#        'org.apache.geronimo.specs:geronimo-jta_1.1_spec',
#        'org.jboss.spec.javax.transaction:jboss-transaction-api_1.2_spec',
#        'org.hibernate:hibernate-validator',
#        'org.eclipse.jetty.websocket:javax-websocket-server-impl',
#        'org.eclipse.jetty.websocket:websocket-client',
#        'jakarta.ws.rs:jakarta.ws.rs-api',
#        'org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_2.0_spec',
#        'org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_2.1_spec',
#        'com.sun.jersey:jersey-core',
#        'org.jboss.spec.javax.xml.bind:jboss-jaxb-api_2.2_spec',
#        'org.jboss.spec.javax.xml.bind:jboss-jaxb-api_2.3_spec',
#        'org.apache.geronimo.specs:geronimo-jaxws_2.1_spec',
#        'javax.annotation:javax.annotation-api',
#        'javax.enterprise:cdi-api',
#        'javax.persistence:javax.persistence-api',
#        'org.jboss.spec.javax.interceptor:jboss-interceptors-api_1.2_spec',
#        'org.springframework:spring-web',
#        'com.sun.xml.stream.buffer:streambuffer', 'jdom:jdom',
#        'org.jvnet.staxex:stax-ex', 'org.jboss:javassist',
#        'org.jfree:jfreechart', 'net.sourceforge.jline:jline',
#        'org.fusesource.jansi:jansi', 'org.jboss.jreadline:jreadline',
#        'org.jline:jline', 'org.jline:jline-builtins',
#        'org.jline:jline-reader', 'org.jline:jline-terminal',
#        'org.jline:jline-terminal-jansi', 'org.jline:jline-terminal-jna',
#        'org.sonatype.jline:jline', 'org.hamcrest:hamcrest-core',
#        'org.jmock:jmock', 'org.jmock:jmock-legacy',
#        'org.threeten:threetenbp', 'javax.servlet:jstl',
#        'com.googlecode.jmockit:jmockit',
#        'org.dspace.dependencies.jmockit:dspace-jmockit', 'jmock:jmock',
#        'org.mockito:mockito-all', 'org.quartz-scheduler:quartz',
#        'net.sourceforge.nekohtml:nekohtml', 'org.ehcache:ehcache',
#        'org.hibernate:hibernate-ehcache', 'au.com.bytecode:opencsv',
#        'com.opencsv:opencsv', 'org.apache.commons:commons-csv',
#        'net.sourceforge.saxon:saxon', 'com.carrotsearch:hppc',
#        'com.google.collections:google-collections',
#        'nu.validator.htmlparser:htmlparser', 'net.sf.saxon:Saxon-HE',
#        'org.mvel:mvel14', 'com.tunnelvisionlabs:antlr4-runtime',
#        'org.codehaus.mojo:javacc-maven-plugin',
#        'org.antlr:antlr4-runtime', 'org.hornetq:hornetq-jms-server',
#        'org.apache.geronimo.specs:geronimo-jms_1.1_spec',
#        'org.fusesource.stompjms:stompjms-client', 'ant:ant',
#        'org.codehaus.plexus:plexus-utils',
#        'com.stratio.cassandra:cassandra-all', 'com.ning:tr13',
#        'commons-io:commons-io', 'commons-lang:commons-lang',
#        'com.blazebit:blaze-persistence-integration-deltaspike-data-api',
#        'com.blazebit:blaze-persistence-integration-deltaspike-data-impl',
#        'org.apache.deltaspike.distribution:distributions-bom',
#        'org.apache.geronimo.config:geronimo-config-impl',
#        'org.apache.geronimo.configs:derby', 'org.talend.esb:derby-all',
#        'org.wisdom-framework:derby',
#        'org.wisdom-framework:mysql-connector-java',
#        'org.apache.geronimo.specs:geronimo-ws-metadata_2.0_spec',
#        'javax.interceptor:javax.interceptor-api', 'javax:javaee-api',
#        'org.apache.openejb:javaee-api', 'javax.ejb:javax.ejb-api',
#        'javax.transaction:javax.transaction-api', 'co.cask.hbase:hbase',
#        'com.google.cloud.bigtable:bigtable-hbase-1.x',
#        'org.apache.atlas:atlas-hbase-client-shaded',
#        'org.apache.atlas:atlas-hbase-server-shaded',
#        'ch.boye.httpclientandroidlib:httpclientandroidlib',
#        'com.networknt:client', 'commons-httpclient:commons-httpclient',
#        'net.ltgt.jaxrs:resteasy-client-okhttp3',
#        'org.apache.httpcomponents.core5:httpcore5',
#        'org.eclipse.jetty:jetty-io', 'io.netty:netty',
#        'com.squareup.okhttp:okhttp',
#        'org.springframework.kafka:spring-kafka',
#        'org.apache.servicemix.bundles:org.apache.servicemix.bundles.lucene',
#        'org.apache.solr:solr', 'org.elasticsearch:elasticsearch',
#        'com.tdunning:t-digest',
#        'org.apache.maven.resolver:maven-resolver-api',
#        'org.apache.maven.resolver:maven-resolver-connector-basic',
#        'org.apache.maven.resolver:maven-resolver-impl',
#        'org.apache.maven.resolver:maven-resolver-spi',
#        'org.apache.maven.resolver:maven-resolver-transport-file',
#        'org.apache.maven.resolver:maven-resolver-transport-http',
#        'org.apache.maven.resolver:maven-resolver-transport-wagon',
#        'org.apache.maven.resolver:maven-resolver-util',
#        'org.apache.maven.artifact:maven-artifact', 'org.sejda:sambox',
#        'org.eclipse.jetty:jetty-plus', 'org.eclipse.jetty:jetty-webapp',
#        'com.alibaba.boot:velocity-spring-boot-starter', 'org.mvel:mvel2',
#        'javax.xml.bind:jaxb-api', 'org.codehaus.groovy:groovy',
#        'org.codehaus.groovy:groovy-templates',
#        'org.apache-extras.beanshell:bsh', 'org.sejda:eventstudio',
#        'org.apache.geronimo.bundles:castor',
#        'org.elasticsearch.module:lang-groovy',
#        'org.jbehave:jbehave-groovy',
#        'org.springframework.cloud:spring-cloud-contract-spec',
#        'org.zkoss.zk:zml', 'org.zkoss.zk:zuljsp',
#        'com.fasterxml.jackson.dataformat:jackson-dataformat-smile',
#        'com.fasterxml.jackson.datatype:jackson-datatype-guava',
#        'com.fasterxml.jackson.datatype:jackson-datatype-json-org',
#        'com.fasterxml.jackson.jaxrs:jackson-jaxrs-base',
#        'com.fasterxml.jackson.jaxrs:jackson-jaxrs-xml-provider',
#        'javax.json:javax.json-api', 'org.jberet:jberet-rest-api',
#        'com.fasterxml.woodstox:woodstox-core',
#        'org.apache.servicemix.bundles:org.apache.servicemix.bundles.woodstox',
#        'org.powermock:powermock-api-mockito',
#        'org.assertj:assertj-assertions-generator', 'org.eclipse.jdt:ecj',
#        'org.eclipse.jetty.websocket:websocket-server',
#        'org.apache.httpcomponents:httpclient-osgi',
#        'org.eclipse.jetty.aggregate:jetty-all', 'org.mortbay.jetty:jetty',
#        'org.mortbay.jetty:jsp-2.1', 'org.mortbay.jetty:jsp-api-2.1',
#        'org.mortbay.jetty:servlet-api-2.5',
#        'org.jboss.spec.javax.servlet:jboss-servlet-api_3.1_spec',
#        'org.mortbay.jetty:jetty-util', 'net.sf.ehcache:ehcache',
#        'org.apache.lucene:lucene-core',
#        'org.elasticsearch.client:elasticsearch-rest-high-level-client',
#        'org.elasticsearch.client:rest',
#        'org.elasticsearch.client:transport',
#        'org.springframework.boot:spring-boot-starter-data-elasticsearch',
#        'org.liquibase:liquibase-core',
#        'com.github.spullara.mustache.java:compiler',
#        'org.apache.velocity:velocity',
#        'org.apache.karaf.shell:org.apache.karaf.shell.console',
#        'com.sun.xml.bind:jaxb-core', 'org.jboss.resteasy:resteasy-jaxrs',
#        'com.sun.jersey:jersey-client',
#        'org.jboss.resteasy:resteasy-client',
#        'com.sun.jersey:jersey-server',
#        'org.jboss.resteasy:resteasy-guice',
#        'org.jboss.resteasy:resteasy-netty4',
#        'com.fasterxml.jackson.dataformat:jackson-dataformat-cbor',
#        'javax.ws.rs:javax.ws.rs-api',
#        'org.springframework.boot:spring-boot-devtools',
#        'org.springframework.boot:spring-boot-starter-data-mongodb',
#        'org.springframework.boot:spring-boot-starter-tomcat',
#        'javax.el:javax.el-api', 'org.hamcrest:hamcrest-integration',
#        'org.hamcrest:hamcrest-library', 'org.hamcrest:java-hamcrest',
#        'org.springframework.boot:spring-boot-starter',
#        'com.google.truth:truth', 'javax.batch:javax.batch-api',
#        'org.eclipse.persistence:org.eclipse.persistence.jpa.jpql',
#        'org.jboss.spec.javax.faces:jboss-jsf-api_2.3_spec',
#        'org.jboss.spec.javax.servlet:jboss-servlet-api_4.0_spec',
#        'org.hibernate.common:hibernate-commons-annotations',
#        'org.mybatis:mybatis', 'org.mybatis:mybatis-spring',
#        'net.sf.ehcache:ehcache-core', 'org.apache.openjpa:openjpa',
#        'org.springframework.boot:spring-boot-starter-data-jpa',
#        'org.hibernate.validator:hibernate-validator',
#        'org.jasig.portal:uportal-db', 'org.jboss.as:jboss-as-clustering',
#        'org.jboss.as:jboss-as-clustering-infinispan',
#        'org.modeshape:modeshape-jcr-api', 'asm:asm',
#        'org.jboss.classfilewriter:jboss-classfilewriter',
#        'org.jboss.forge:forge-javassist',
#        'org.jboss.arquillian:arquillian-bom',
#        'org.wildfly.arquillian:wildfly-arquillian-container-managed',
#        'org.wildfly:wildfly-arquillian-container-managed',
#        'io.netty:netty-handler',
#        'org.eclipse.jetty.websocket:websocket-api',
#        'org.eclipse.jetty.websocket:websocket-common',
#        'javax.ws.rs:jsr311-api',
#        'org.jboss.spec.javax.ejb:jboss-ejb-api_3.1_spec',
#        'org.jboss.spec.javax.servlet:jboss-servlet-api_3.0_spec',
#        'org.glassfish.jersey.media:jersey-media-jaxb',
#        'org.eclipse.aether:aether-api',
#        'org.eclipse.aether:aether-connector-file',
#        'org.eclipse.aether:aether-connector-wagon',
#        'org.eclipse.aether:aether-impl',
#        'org.eclipse.aether:aether-transport-file',
#        'org.eclipse.aether:aether-transport-http',
#        'com.google.jimfs:jimfs', 'org.jboss.as:jboss-as-transactions',
#        'org.jboss.shrinkwrap.descriptors:shrinkwrap-descriptors-bom',
#        'org.jboss.shrinkwrap.resolver:shrinkwrap-resolver-depchain',
#        'org.jboss.spec.javax.faces:jboss-jsf-api_2.2_spec',
#        'io.undertow:undertow-servlet',
#        'io.undertow:undertow-websockets-jsr', 'javax.servlet:servlet-api',
#        'org.jboss.spec.javax.websocket:jboss-websocket-api_1.0_spec',
#        'org.jboss.weld.se:weld-se-core',
#        'org.apache.servicemix.bundles:org.apache.servicemix.bundles.jdom',
#        'org.aksw.jena-sparql-api:jena-sparql-api-jgrapht', 'jline:jline',
#        'org.hamcrest:hamcrest-all',
#        'org.ldp4j.framework:ldp4j-application-bom',
#        'org.ldp4j.framework:ldp4j-application-data',
#        'org.ldp4j.framework:ldp4j-application-examples',
#        'com.googlecode.json-simple:json-simple', 'com.tdunning:json',
#        'com.unboundid.components:json',
#        'com.vaadin.external.google:android-json',
#        'org.apache.felix:org.apache.felix.utils',
#        'org.apache.johnzon:johnzon-core',
#        'org.codehaus.jackson:jackson-xc',
#        'org.codehaus.jettison:jettison',
#        'net.htmlparser.jericho:jericho-html', 'org.lwjgl:lwjgl',
#        'org.lwjgl:lwjgl-glfw', 'org.lwjgl:lwjgl-openal',
#        'org.lwjgl:lwjgl-opengl', 'org.lwjgl:lwjgl-platform',
#        'org.postgresql:postgresql', 'org.powermock:powermock-core',
#        'org.eclipse.jetty.aggregate:jetty-all-server',
#        'org.eclipse.jetty:jetty-continuation',
#        'org.eclipse.jetty:jetty-deploy', 'org.eclipse.jetty:jetty-jmx',
#        'org.eclipse.jetty:jetty-jsp', 'org.eclipse.jetty:jetty-jsp-2.1',
#        'org.eclipse.jetty:jetty-security',
#        'org.eclipse.jetty:jetty-servlets', 'org.eclipse.jetty:jetty-util',
#        'org.eclipse.jetty:jetty-util-ajax', 'org.eclipse.jetty:jetty-xml',
#        'org.jboss.errai:errai-cdi-jboss', 'org.cometd.java:bayeux-api',
#        'com.baomidou:mybatis-plus-boot-starter',
#        'com.baomidou:mybatis-plus-generator',
#        'tk.mybatis:mapper-spring-boot-starter',
#        'com.baomidou:mybatis-plus-extension',
#        'org.mybatis.generator:mybatis-generator-core',
#        'org.mybatis.spring.boot:mybatis-spring-boot-starter',
#        'com.buschmais.xo:xo.neo4j.api',
#        'org.neo4j.doc:neo4j-cypher-docs-parent',
#        'org.neo4j.doc:neo4j-manual',
#        'org.neo4j.doc:neo4j-manual-contents',
#        'org.apache.felix:org.apache.felix.framework',
#        'org.apache.karaf:org.apache.karaf.main', 'asm:asm-commons',
#        'org.apache.flink:flink-shaded-asm', 'com.jtransc:jtransc-asm',
#        'org.apache.xbean:xbean-asm-shaded', 'org.jinq:jinq-asm-rebased',
#        'org.glassfish.hk2.external:asm-repackaged',
#        'io.vertx:vertx-mysql-postgresql-client',
#        'org.ancoron.postgresql:org.postgresql',
#        'org.jumpmind.symmetric.jdbc:postgresql',
#        'org.mariadb.jdbc:mariadb-java-client',
#        'org.powermock:powermock-api-mockito2',
#        'org.jetbrains.kotlin:kotlin-stdlib',
#        'org.jetbrains.kotlin:kotlin-stdlib-jdk8',
#        'com.puppycrawl.tools:checkstyle',
#        'eu.infomas:annotation-detector',
#        'io.github.lukehutch:fast-classpath-scanner',
#        'com.github.scribejava:scribejava-apis',
#        'com.github.scribejava:scribejava-core',
#        'org.jboss.arquillian.selenium:selenium-bom',
#        'com.google.inject.extensions:guice-assistedinject',
#        'com.google.inject.extensions:guice-multibindings',
#        'org.springframework.cloud:spring-cloud-dependencies',
#        'org.springframework.cloud:spring-cloud-starter-stream-rabbit',
#        'org.springframework:spring-aop',
#        'com.github.pagehelper:pagehelper', 'tk.mybatis:mapper',
#        'org.springframework.data:spring-data-redis',
#        'org.springframework.security:spring-security-config',
#        'org.thymeleaf.extras:thymeleaf-extras-springsecurity4',
#        'org.thymeleaf:thymeleaf', 'org.thymeleaf:thymeleaf-spring4',
#        'org.springframework.cloud:spring-cloud-starter-gateway',
#        'org.springframework:spring-messaging',
#        'org.springframework:spring-websocket',
#        'org.springframework.boot:spring-boot-starter-data-redis',
#        'org.springframework.boot:spring-boot-starter-hateoas',
#        'org.apache.kafka:kafka-clients', 'io.jsonwebtoken:jjwt',
#        'org.springframework.cloud:spring-cloud-security',
#        'org.springframework.cloud:spring-cloud-starter-oauth2',
#        'org.springframework.boot:spring-boot-starter-aop',
#        'org.springframework.boot:spring-boot-starter-thymeleaf',
#        'net.java.dev.glazedlists:glazedlists_java15',
#        'org.swinglabs.swingx:swingx-all',
#        'org.ocpsoft.rewrite:rewrite-servlet',
#        'de.agilecoders.wicket:wicket-bootstrap-core',
#        'org.iq80.snappy:snappy',
#        'com.fasterxml.jackson.dataformat:jackson-dataformat-yaml',
#        'com.impossibl.pgjdbc-ng:pgjdbc-ng', 'io.lettuce:lettuce-core',
#        'org.springframework.boot:spring-boot-starter-redis',
#        'org.springframework.integration:spring-integration-redis',
#        'org.mozilla:rhino', 'com.rometools:rome', 'xom:xom',
#        'ru.qatools.commons:properties', 'javax.xml.stream:stax-api',
#        'org.apache.geronimo.specs:geronimo-stax-api_1.0_spec',
#        'org.codehaus.woodstox:woodstox-core-asl',
#        'org.apache.taglibs:taglibs-standard-impl',
#        'org.apache.taglibs:taglibs-standard-spec',
#        'org.apache.velocity:velocity-tools',
#        'com.sun.enterprise:stax-osgi', 'org.codehaus.woodstox:wstx-asl',
#        'org.opengis.cite.xerces:xercesImpl-xsd11',
#        'org.simpleframework:simple-xml', 'org.ogce:xpp3'], dtype=object)

# %%
test_unit_df['toLib'].unique()
# Out:
# array(['org.apache.ant:ant-junit',
#        'com.google.testing.compile:compile-testing',
#        'org.glassfish.jersey.test-framework.providers:jersey-test-framework-provider-jetty',
#        'org.glassfish.jersey.test-framework.providers:jersey-test-framework-provider-grizzly2',
#        'net.sourceforge.htmlunit:htmlunit', 'org.httpunit:httpunit',
#        'io.cucumber:cucumber-junit',
#        'org.springframework.boot:spring-boot-test',
#        'org.springframework.boot:spring-boot-test-autoconfigure',
#        'org.springframework:spring-test', 'org.jmock:jmock-junit3',
#        'org.jmock:jmock-junit4', 'org.junit.jupiter:junit-jupiter',
#        'org.junit.jupiter:junit-jupiter-api',
#        'org.junit.jupiter:junit-jupiter-engine',
#        'org.junit.jupiter:junit-jupiter-migrationsupport',
#        'org.junit.jupiter:junit-jupiter-params',
#        'org.junit.platform:junit-platform-launcher',
#        'org.junit.platform:junit-platform-runner',
#        'org.junit.platform:junit-platform-surefire-provider',
#        'org.junit.vintage:junit-vintage-engine',
#        'org.mockito:mockito-junit-jupiter',
#        'org.openengsb.core:openengsb-core-test',
#        'org.springframework.boot:spring-boot-starter-test',
#        'org.testng:testng',
#        'net.sourceforge.jwebunit:jwebunit-htmlunit-plugin', 'junit:junit',
#        'org.xmlunit:xmlunit-matchers', 'junit:junit-dep',
#        'org.easytesting:fest-assert', 'org.easytesting:fest-assert-core',
#        'org.xwiki.commons:xwiki-commons-test-component',
#        'org.arquillian.universe:arquillian-junit',
#        'org.jboss.arquillian.junit:arquillian-junit-container',
#        'io.ap4k:kubernetes-junit-starter',
#        'io.ap4k:openshift-junit-starter', 'org.scalatest:scalatest_2.12',
#        'org.junit.platform:junit-platform-console', 'org.junit:junit-bom',
#        'io.vertx:vertx-junit5',
#        'org.codehaus.sonar:sonar-testing-harness',
#        'org.powermock:powermock-module-junit4',
#        'org.neo4j.doc:neo4j-cypher-refcard-tests',
#        'org.neo4j.test:neo4j-harness', 'org.jetbrains.kotlin:kotlin-test',
#        'org.junit.platform:junit-platform-commons',
#        'com.github.ryanbrainard:richsobjects-api-provider-base-tests',
#        'com.tngtech.java:junit-dataprovider',
#        'org.apache.lucene:lucene-test-framework',
#        'org.jboss.arquillian.ajocado:arquillian-ajocado-junit',
#        'org.jboss.arquillian:arquillian-junit',
#        'org.xmlunit:xmlunit-core', 'org.xmlunit:xmlunit-legacy'],
#       dtype=object)

# %%
log_df['toLib'].unique()
# Out:
# array(['org.apache.logging.log4j:log4j-api',
#        'org.apache.logging.log4j:log4j-core',
#        'org.apache.logging.log4j:log4j-jcl',
#        'org.apache.logging.log4j:log4j-slf4j-impl', 'log4j:log4j',
#        'org.slf4j:jcl-over-slf4j', 'org.slf4j:log4j-over-slf4j',
#        'org.slf4j:slf4j-api', 'org.slf4j:slf4j-jdk14',
#        'org.slf4j:slf4j-log4j12', 'org.slf4j:slf4j-nop',
#        'org.slf4j:slf4j-simple',
#        'org.springframework.boot:spring-boot-starter-logging',
#        'org.apache.logging.log4j.adapters:log4j-slf4j-impl',
#        'org.kevoree:org.kevoree.log', 'ch.qos.logback:logback-classic',
#        'ch.qos.logback:logback-core',
#        'org.jboss.logging:commons-logging-jboss-logging',
#        'org.ops4j.pax.logging:pax-logging-api',
#        'org.jboss.logging:jboss-logging',
#        'org.jboss.logging:jboss-logging-processor',
#        'org.apache.tomcat.embed:tomcat-embed-logging-juli',
#        'commons-logging:commons-logging',
#        'commons-logging:commons-logging-api',
#        'org.apache.logging.log4j:log4j-1.2-api', 'org.slf4j:slf4j-ext',
#        'org.slf4j:slf4j-jcl', 'log4j:apache-log4j-extras',
#        'org.slf4j:jul-to-slf4j',
#        'org.springframework.boot:spring-boot-starter-log4j2',
#        'org.jboss.logmanager:commons-logging-jboss-logmanager',
#        'org.apache.logging.log4j:log4j-jul',
#        'org.apache.logging.log4j:log4j-to-slf4j',
#        'com.github.tony19:logback-android-classic', 'io.airlift:log',
#        'org.jboss.logging:jboss-logging-annotations',
#        'org.jboss.logmanager:jboss-logmanager',
#        'org.apache.logging.log4j:log4j-web', 'org.spf4j:spf4j-slf4j-test'],
#       dtype=object)

# %%
print(len(remain_df['repoName'].unique()))
print(len(test_unit_df['repoName'].unique()))
print(len(log_df['repoName'].unique()))
# Out:
# 1278
# 265
# 469

# %%
log_sample_df = log_df.sample(n=500, random_state=seed)
test_sample_df = test_unit_df.sample(n=500, random_state=seed)
others_sample_df = remain_df.sample(n=500, random_state=seed)

# %%
log_sample_df.to_parquet(f'{data_prefix}/500_log_sample_no_code.parquet')
test_sample_df.to_parquet(f'{data_prefix}/500_test_sample_no_code.parquet')
others_sample_df.to_parquet(f'{data_prefix}/500_others_sample_no_code.parquet')
