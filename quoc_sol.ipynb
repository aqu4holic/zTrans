# %%
import pandas as pd
data = pd.read_parquet('/drive2/phatnt/zTrans/data/migration_others_method_no_code.parquet')
data
# Out:
#             id                                         fromLib  \
# 0            0                                         ant:ant
# 1            1                                         ant:ant
# 2            2                                         ant:ant
# 3            3                                         ant:ant
# 4            4                                         ant:ant
# ...        ...                                             ...
# 171774  171774  ru.yandex.qatools.properties:properties-loader
# 171775  171775  ru.yandex.qatools.properties:properties-loader
# 171776  171776  ru.yandex.qatools.properties:properties-loader
# 171777  171777  ru.yandex.qatools.properties:properties-loader
# 171778  171778                                 xstream:xstream
#
#                                    toLib  \
# 0                     org.apache.ant:ant
# 1                     org.apache.ant:ant
# 2                     org.apache.ant:ant
# ...

# %%
data = data[(data['method_before'].str.len() > 0) & (data['method_after'].str.len() > 0)]
data
# Out:
#             id                                         fromLib  \
# 0            0                                         ant:ant
# 1            1                                         ant:ant
# 2            2                                         ant:ant
# 3            3                                         ant:ant
# 4            4                                         ant:ant
# ...        ...                                             ...
# 171773  171773  ru.yandex.qatools.properties:properties-loader
# 171774  171774  ru.yandex.qatools.properties:properties-loader
# 171775  171775  ru.yandex.qatools.properties:properties-loader
# 171776  171776  ru.yandex.qatools.properties:properties-loader
# 171778  171778                                 xstream:xstream
#
#                                    toLib  \
# 0                     org.apache.ant:ant
# 1                     org.apache.ant:ant
# 2                     org.apache.ant:ant
# ...

# %%
data.columns
# Out:
# Index(['id', 'fromLib', 'toLib', 'repoName', 'prevCommit', 'startCommit',
#        'endCommit', 'fileName', 'startCommitChanges', 'endCommitChanges',
#        'total_methods_before', 'total_methods_after', 'class_before',
#        'class_after', 'method_before_name', 'method_after_name',
#        'method_before', 'method_after', 'method_diff',
#        'method_before_modifiers', 'method_after_modifiers',
#        'method_before_return_type', 'method_after_return_type',
#        'method_before_parameters', 'method_after_parameters',
#        'method_before_signature', 'method_after_signature',
#        'method_before_signature_no_mod', 'method_after_signature_no_mod'],
#       dtype='object')

# %%
index = 200
print(data.iloc[index]['class_before'])
print('---->')
print(data.iloc[index]['class_after'])
print('---->')
print(data.iloc[index]['startCommitChanges'])
print('---->')
print(data.iloc[index]['endCommitChanges'])
print('---->')
print(data.iloc[index]['fromLib'])
print('---->')
print(data.iloc[index]['toLib'])
print('---->')
print(data.iloc[index]['method_before'])
print('---->')
print(data.iloc[index]['method_after'])
print('---->')
print(data.iloc[index]['method_diff'])
# Out:
# FromNodeTest
# ---->
# FromNodeTest
# ---->
# +org.mockito:mockito-all
# ---->
# -org.jmock:jmock
# -org.jmock:jmock-legacy
# ---->
# ant:ant
# ---->
# org.apache.ant:ant
# ---->
# public void testRestract() {
#         final PropagationContext context = new PropagationContextImpl( 0,
#                                                                        PropagationContext.ASSERTION,
#                                                                        null,
#                                                                        null,
#                                                                        null );
#         final ReteooWorkingMemory workingMemory = new ReteooWorkingMemory( 1,
#                                                                            (ReteooRuleBase) RuleBaseFactory.newRuleBase() );
#         final ClassFieldReader extractor = store.getReader( Cheese.class,
#                                                                   "type",
# ...
