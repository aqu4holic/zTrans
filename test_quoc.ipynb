# %%
import pandas as pd
data = pd.read_parquet('/drive2/phatnt/zTrans/data/migration_others_method_no_code.parquet',engine = 'pyarrow')

# %%
data
# Out:
#             id                                         fromLib  \
# 0            0                                         ant:ant
# 1            1                                         ant:ant
# 2            2                                         ant:ant
# 3            3                                         ant:ant
# 4            4                                         ant:ant
# ...        ...                                             ...
# 171774  171774  ru.yandex.qatools.properties:properties-loader
# 171775  171775  ru.yandex.qatools.properties:properties-loader
# 171776  171776  ru.yandex.qatools.properties:properties-loader
# 171777  171777  ru.yandex.qatools.properties:properties-loader
# 171778  171778                                 xstream:xstream
#
#                                    toLib  \
# 0                     org.apache.ant:ant
# 1                     org.apache.ant:ant
# 2                     org.apache.ant:ant
# ...

# %%
data1 = data[data['startCommit'] == data['endCommit']]
data1
# Out:
#             id                                         fromLib  \
# 556        556                                         ant:ant
# 557        557                                         ant:ant
# 558        558                                         ant:ant
# 559        559                                         ant:ant
# 560        560                                         ant:ant
# ...        ...                                             ...
# 171774  171774  ru.yandex.qatools.properties:properties-loader
# 171775  171775  ru.yandex.qatools.properties:properties-loader
# 171776  171776  ru.yandex.qatools.properties:properties-loader
# 171777  171777  ru.yandex.qatools.properties:properties-loader
# 171778  171778                                 xstream:xstream
#
#                                    toLib  \
# 556                   org.apache.ant:ant
# 557                   org.apache.ant:ant
# 558                   org.apache.ant:ant
# ...

# %%
data1 = data1[data1['repoName'] == 'teiid_teiid']
data1
# Out:
#       id  fromLib               toLib     repoName  \
# 556  556  ant:ant  org.apache.ant:ant  teiid_teiid
# 557  557  ant:ant  org.apache.ant:ant  teiid_teiid
# 558  558  ant:ant  org.apache.ant:ant  teiid_teiid
# 559  559  ant:ant  org.apache.ant:ant  teiid_teiid
# 560  560  ant:ant  org.apache.ant:ant  teiid_teiid
# ..   ...      ...                 ...          ...
# 841  841  ant:ant  org.apache.ant:ant  teiid_teiid
# 842  842  ant:ant  org.apache.ant:ant  teiid_teiid
# 843  843  ant:ant  org.apache.ant:ant  teiid_teiid
# 844  844  ant:ant  org.apache.ant:ant  teiid_teiid
# 845  845  ant:ant  org.apache.ant:ant  teiid_teiid
#
#                                    prevCommit  \
# 556  ff5528d89c69c6e5347c43ee23287bce84380b85
# 557  ff5528d89c69c6e5347c43ee23287bce84380b85
# 558  ff5528d89c69c6e5347c43ee23287bce84380b85
# 559  ff5528d89c69c6e5347c43ee23287bce84380b85
# 560  ff5528d89c69c6e5347c43ee23287bce84380b85
# ..                                        ...
# ...

# %%
data1 = data1.groupby('fileName').agg({
    'id': 'count'
}).rename(columns={'id': 'count'})  
data1 = data1.sort_values(by='count', ascending=False)
data1
# Out:
#                                                     count
# fileName
# engine/src/test/java/org/teiid/query/function/T...     26
# engine/src/main/java/org/teiid/query/sql/lang/T...     18
# engine/src/test/java/org/teiid/query/function/T...     17
# engine/src/test/java/org/teiid/query/sql/symbol...     17
# engine/src/test/java/org/teiid/query/optimizer/...     16
# ...                                                   ...
# engine/src/main/java/org/teiid/query/sql/symbol...      1
# engine/src/main/java/org/teiid/query/resolver/u...      1
# engine/src/test/java/org/teiid/query/sql/proc/T...      1
# engine/src/test/java/org/teiid/query/sql/visito...      1
# jboss-integration/src/main/java/org/teiid/jboss...      1
#
# [63 rows x 1 columns]

# %%
t = data[data['fileName'] == 'engine/src/test/java/org/teiid/query/function/TestFunction.java']
t[['method_before','method_after']]
# Out:
#                                          method_before  \
# 707  @Test public void testTimestampDiffTimeStamp_F...
# 708  @Test public void testTimestampDiffTimeStamp_F...
# 709  @Test public void testTimestampDiffTimeStamp_F...
# 710  @Test public void testTimestampDiffTimeStamp_F...
# 711  @Test public void testTimestampDiffTimeStamp_F...
# 712  @Test public void testTimestampDiffTime_Hour_1...
# 713  @Test public void testTimestampDiffTimeStamp_F...
# 714  @Test public void testTimestampDiffTimeStamp_M...
# 715  @Test public void testTimestampDiffTimeStamp_M...
# 716  @Test public void testTimestampDiffTimeStamp_H...
# 717  @Test public void testTimestampDiffTimeStamp_M...
# 718  @Test public void testTimestampDiffTimeStamp_M...
# 719  @Test public void testTimestampDiffTimeStamp_M...
# 720  @Test public void testTimestampDiffTimeStamp_M...
# 721  @Test public void testTimestampDiffTimeStamp_W...
# 722  @Test public void testTimestampDiffTimeStamp_D...
# ...
